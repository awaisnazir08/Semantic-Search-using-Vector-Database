# %%
import pandas as pd
import numpy as np
import glob
import requests
import json
import torch
import clip
import pymilvus
from pymilvus import (
    connections,
    utility,
    FieldSchema,
    CollectionSchema,
    DataType,
    Collection,
    db
)

# %%
titles_data = pd.read_parquet('title_embeddings/metadata/metadata_0.parquet')
IMAGES_URL_DIRECTORY = 'image_folder'

# %%
titles_data.head()
# Out:
#                                              caption
# 0  Howard LC0008 Leather Conditioner, 8-Ounce (4-...
# 1  Yes to Tomatoes Detoxifying Charcoal Cleanser ...
# 2  Avon Big & False Lash Mascara - Brown/Black by...
# 3  Amybria New Silver Plated Full Crystal Inlay B...
# 4  Lucky 7 Shaving Starter Set - Seven Blade Shav...

# %%
len(titles_data)
# Out:
# 112590

# %%
title_embeddings = np.load('title_embeddings/text_emb/text_emb_0.npy')

# %%
title_embeddings.shape
# Out:
# (112590, 512)

# %%
images_data = pd.read_parquet('image_folder/00000.parquet')

# %%
images_data.head()
# Out:
#                                                  url        key   status  \
# 0  https://m.media-amazon.com/images/I/517uoA+-gz...  000000016  success
# 1  https://m.media-amazon.com/images/I/510BWq7O95...  000000015  success
# 2  https://m.media-amazon.com/images/I/71g1lP0pMb...  000000002  success
# 3  https://m.media-amazon.com/images/I/513VyUt42Y...  000000018  success
# 4  https://m.media-amazon.com/images/I/511v5MygzT...  000000017  success
#
#   error_message  width  height  original_width  original_height exif  \
# 0          None  224.0   224.0          1005.0           1005.0   {}
# 1          None  224.0   224.0          1005.0           1005.0   {}
# 2          None  224.0   224.0           540.0           1500.0   {}
# 3          None  224.0   224.0          1005.0           1005.0   {}
# 4          None  224.0   224.0          1005.0           1005.0   {}
#
#                                               sha256
# 0  d9bbcad7ec92ac4883378b3c4c02115fb368e85918fb56...
# 1  39d9ae4617737dcbf3d8ba0c655e8b5ac70cfc955dee25...
# 2  fc7df6df54aeb9b681713a5850d74591f011476343e135...
# 3  3800225ab55c760e8ec749f907c87382afd02d8c85489f...
# 4  f68a9d335bbc13c5f22796d0421a69dd03bc3949ee5dff...

# %%
images_data.shape
# Out:
# (10000, 10)

# %%
url_key_dict = images_data.set_index('url')['key'].to_dict()

# Display the dictionary
print(url_key_dict)
# Out:
# {'https://m.media-amazon.com/images/I/517uoA+-gzL._SL1005_.jpg': '000000016', 'https://m.media-amazon.com/images/I/510BWq7O95L._SL1005_.jpg': '000000015', 'https://m.media-amazon.com/images/I/71g1lP0pMbL._SL1500_.jpg': '000000002', 'https://m.media-amazon.com/images/I/513VyUt42YL._SL1005_.jpg': '000000018', 'https://m.media-amazon.com/images/I/511v5MygzTL._SL1005_.jpg': '000000017', 'https://m.media-amazon.com/images/I/31bz+uqzWCL.jpg': '000000005', 'https://m.media-amazon.com/images/I/71i77AuI9xL._SL1500_.jpg': '000000001', 'https://m.media-amazon.com/images/I/61NS1lONhzL._SL1001_.jpg': '000000007', 'https://m.media-amazon.com/images/I/51+ERW-6D0L._SL1005_.jpg': '000000021', 'https://m.media-amazon.com/images/I/81OqvR94isL._SL1500_.jpg': '000000003', 'https://m.media-amazon.com/images/I/51f2sDEVH7L._SL1005_.jpg': '000000020', 'https://m.media-amazon.com/images/I/61m-71vCbCL._SL1001_.jpg': '000000012', 'https://m.media-amazon.com/images/I/31TgqAZ8kQL.jpg': '000000013', 'https://m.media-amazon.com/images/I/41qfjSfqNyL.jpg': '000000000', 'https://m.media-amazon.com/images/I/61iomcZjbAL._SL1001_.jpg': '000000011', 'https://m.media-amazon.com/images/I/618BBBsAQrL._SL1001_.jpg': '000000010', 'https://m.media-amazon.com/images/I/51T546q1UzL._SL1005_.jpg': '000000022', 'https://m.media-amazon.com/images/I/612NVdL0gDL._SL1005_.jpg': '000000019', 'https://m.media-amazon.com/images/I/61G-iZeX-LL._SL1001_.jpg': '000000009', 'https://m.media-amazon.com/images/I/81fx2PsCbcL._SL1500_.jpg': '000000040', 'https://m.media-amazon.com/images/I/614-X9xG+UL._SL1500_.jpg': '000000044', 'https://m.media-amazon.com/images/I/81p2syDoGeL._SL1500_.jpg': '000000041', 'https://m.media-amazon.com/images/I/41a1Sj7Q20L._SL1005_.jpg': '000000014', 'https://m.media-amazon.com/images/I/71Mr93aVo+L._SL1500_.jpg': '000000031', 'https://m.media-amazon.com/images/I/810s1yPUJgL._SL1500_.jpg': '000000028', 'https://m.media-amazon.com/images/I/71eeT1V8nDL._SL1000_.jpg': '000000026', 'https://m.media-amazon.com/images/I/71xFb7Y9gZL._SL1500_.jpg': '000000034', 'https://m.media-amazon.com/images/I/71aPPNO7hML._SL1000_.jpg': '000000027', 'https://m.media-amazon.com/images/I/713Z24d6hVS._SL1200_.jpg': '000000024', 'https://m.media-amazon.com/images/I/81udu+NP2RL._SL1500_.jpg': '000000032', 'https://m.media-amazon.com/images/I/61lcwXtw3ZL._SL1001_.jpg': '000000008', 'https://m.media-amazon.com/images/I/817Nj6u5zML._SL1500_.jpg': '000000025', 'https://m.media-amazon.com/images/I/81MIq-+Z0dL._SL1500_.jpg': '000000030', 'https://m.media-amazon.com/images/I/81uzSAYAdKL._SL1500_.jpg': '000000039', 'https://m.media-amazon.com/images/I/51Z7OjMfnuL._SL1001_.jpg': '000000057', 'https://m.media-amazon.com/images/I/51Zx-56tzCS.jpg': '000000065', 'https://m.media-amazon.com/images/I/61W4Qf84pKL._SL1001_.jpg': '000000054', 'https://m.media-amazon.com/images/I/61CtWDPoN0L._SL1001_.jpg': '000000053', 'https://m.media-amazon.com/images/I/71jrogkcveL._SL1500_.jpg': '000000023', 'https://m.media-amazon.com/images/I/51+ZybuR3sS.jpg': '000000064', 'https://m.media-amazon.com/images/I/71GJhXQGvyL._SL1500_.jpg': '000000006', 'https://m.media-amazon.com/images/I/71ZKyAQreOL._SL1500_.jpg': '000000072', 'https://m.media-amazon.com/images/I/61DUHvjkpKS._SL1000_.jpg': '000000063', 'https://m.media-amazon.com/images/I/51Ih9eSi3SL._SL1001_.jpg': '000000059', 'https://m.media-amazon.com/images/I/9118ClZ71fL._SL1500_.jpg': '000000035', 'https://m.media-amazon.com/images/I/51TTTf0hZjL._SL1000_.jpg': '000000043', 'https://m.media-amazon.com/images/I/71p2er91bHL._SL1500_.jpg': '000000070', 'https://m.media-amazon.com/images/I/41gK+K5o57L.jpg': '000000060', 'https://m.media-amazon.com/images/I/51MJW+ULbhS.jpg': '000000066', 'https://m.media-amazon.com/images/I/71U6hl1ancL._SL1500_.jpg': '000000069', 'https://m.media-amazon.com/images/I/51q0Qxz-+4L._SL1001_.jpg': '000000055', 'https://m.media-amazon.com/images/I/71fBr11VBZL._SL1264_.jpg': '000000047', 'https://m.media-amazon.com/images/I/615N6fkcn9L._SL1500_. ...

# %%
image_embeddings_meta_data = pd.read_parquet('image_embeddings_complete\metadata\metadata_0.parquet')
image_embeddings_meta_data.head(520000)
# Out:
#                               image_path
# 0       image_folder/00000/000000000.jpg
# 1       image_folder/00000/000000001.jpg
# 2       image_folder/00000/000000002.jpg
# 3       image_folder/00000/000000003.jpg
# 4       image_folder/00000/000000004.jpg
# ...                                  ...
# 519995  image_folder/00052/000521073.jpg
# 519996  image_folder/00052/000521074.jpg
# 519997  image_folder/00052/000521075.jpg
# 519998  image_folder/00052/000521076.jpg
# 519999  image_folder/00052/000521077.jpg
#
# [520000 rows x 1 columns]

# %%
image_embeddings_meta_data['key'] = image_embeddings_meta_data['image_path'].str.extract(r'(\d{9})')
image_embeddings_meta_data.head(520000)
# Out:
#                               image_path        key
# 0       image_folder/00000/000000000.jpg  000000000
# 1       image_folder/00000/000000001.jpg  000000001
# 2       image_folder/00000/000000002.jpg  000000002
# 3       image_folder/00000/000000003.jpg  000000003
# 4       image_folder/00000/000000004.jpg  000000004
# ...                                  ...        ...
# 519995  image_folder/00052/000521073.jpg  000521073
# 519996  image_folder/00052/000521074.jpg  000521074
# 519997  image_folder/00052/000521075.jpg  000521075
# 519998  image_folder/00052/000521076.jpg  000521076
# 519999  image_folder/00052/000521077.jpg  000521077
#
# [520000 rows x 2 columns]

# %%
image_embeddings_meta_data.shape
# Out:
# (548083, 1)

# %%
index_value = image_embeddings_meta_data.loc[image_embeddings_meta_data['key'] == '000010004'].index
index_value.empty
# Out:
# True

# %%
d = {'dfadf':21}
d.update({'ds':32})
d
# Out:
# {'dfadf': 21, 'ds': 32}

# %%
def creating_images_url_dictionary(path = IMAGES_URL_DIRECTORY):
# Initialize an empty dictionary
    url_key_dict = {}

    # List of file paths (adjust the path and extension as needed)
    file_paths = glob.glob(f'{path}/*.parquet')
    
    # print(len(file_paths))
    
    for file_path in file_paths:
        # Read the file into a DataFrame
        data = pd.read_parquet(file_path)
        
        # Ensure the key column is in string format
        data['key'] = data['key'].astype(str)
        
        # Update the dictionary with data from the current file
        url_key_dict.update(data.set_index('url')['key'].to_dict())
    
    return url_key_dict

# %%
images_url_dictionary = creating_images_url_dictionary()
# Out:
# 55

# %%
print(len(images_url_dictionary))
# Out:
# 478384

# %%
print(images_url_dictionary['https://m.media-amazon.com/images/I/71jV-W1EJHS._SL1001_.jpg'])
# Out:
# 000276268

# %%
image_embeddings = np.load('image_embeddings_complete\img_emb\img_emb_0.npy')
image_embeddings.shape
# Out:
# (548083, 512)
